# %% [markdown]
# ## Bias correction
#
# The aim is to debias the Climex2 data. ERA5-land is used as a reference here. The ibicus package is used here for bias correcting the data. The debias functions from ibicus require observations, model historical period, model future period.
#
# Here we are going to use the midday temperature values with the following time periods:
# - Observation: ERA5-land  (1991 - 2010)
# - Historical: CLIMEX (1991- 2010)
# - Future: CLIMEX 20 years to select to bias correct

# %% [markdown]
# ### User input
#
# The user input required is:
# - Future time period (20 years is required, provide start date)
# - Bias correcting method
# - Ensemble for Climex2 data
# - Variable to debias + corresponding path

# %%
import sys
import glob
import xarray as xr
import numpy as np
from dask.distributed import LocalCluster
from ibicus.debias import LinearScaling, DeltaChange, QuantileMapping, CDFt, ISIMIP, ScaledDistributionMapping
import time
import dask.array as da 
import os

# %%
t0 = time.time()
baseline_env = 'hpp'
ens = 'hpp'
bias_correct = 'LS'
start_year = '1991'
end_year = '2010'
var = 'wind'

# %%
# Used for visualisation purposes
#client = LocalCluster().get_client()
# Out:
# 2025-03-28 15:57:06,620 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 51289060d55bb93ae6d856c56ebddc08 initialized by task ('rechunk-merge-rechunk-transfer-3f7eb945205a62ade7e1b25e901c1590', 0, 0, 0, 9, 0, 0) executed on worker tcp://127.0.0.1:55607
# 2025-03-28 15:57:29,817 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c0ded05cbb7255a831cc1ec530ad6b initialized by task ('rechunk-merge-rechunk-transfer-34c43c08970f372f3f53ae8564180536', 0, 0, 0, 49, 0, 0) executed on worker tcp://127.0.0.1:55607
# 2025-03-28 15:57:40,622 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 51289060d55bb93ae6d856c56ebddc08 deactivated due to stimulus 'task-finished-1743173860.6164513'
# 2025-03-28 15:58:27,375 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c0ded05cbb7255a831cc1ec530ad6b deactivated due to stimulus 'task-finished-1743173907.3684692'
# 2025-03-28 16:01:35,829 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 51289060d55bb93ae6d856c56ebddc08 initialized by task ('rechunk-merge-rechunk-transfer-3f7eb945205a62ade7e1b25e901c1590', 0, 0, 0, 9, 0, 0) executed on worker tcp://127.0.0.1:55607
# 2025-03-28 16:01:47,364 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 51289060d55bb93ae6d856c56ebddc08 deactivated due to stimulus 'task-finished-1743174107.3604226'
# 2025-03-28 16:01:58,031 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c0ded05cbb7255a831cc1ec530ad6b initialized by task ('rechunk-merge-rechunk-transfer-34c43c08970f372f3f53ae8564180536', 0, 0, 0, 9, 0, 0) executed on worker tcp://127.0.0.1:55614
# 2025-03-28 16:02:32,285 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c0ded05cbb7255a831cc1ec530ad6b deactivated due to stimulus 'task-finished-1743174152.279555'

# %%
#client
# Out:
# <Client: 'tcp://127.0.0.1:55585' processes=4 threads=12, memory=31.65 GiB>

# %% [markdown]
# ### 2. Load files & preprocess data

# %% [markdown]
# #### Load climex data - historical (1991 - 2010)

# %%
years = np.arange(1991, 2011)
path = "O:/Climate-and-Energy-Policy/CERM/Projects/Wildfire/Data/CLIMEX2/FWI-variables/"

files = []

for year in years:
    year = str(year)
    files = files + sorted(glob.glob(path +'/'+ baseline_env + '/' + var + '-' + year + '*.nc')) # Select only June to October

# %%
len(files)/5 # Only considering 5months / year
# Out:
# 20.0

# %%
# %%time
ds_hist = xr.open_mfdataset(files)
# Out:
# CPU times: total: 44.5 s
# Wall time: 1min 10s

# %%
ds_hist = ds_hist.wind

# %%
ds_hist = ds_hist.chunk(chunks={'rlat': 20, 'rlon': 20, 'time': -1})

# %%
len(ds_hist.time)
# Out:
# 3060

# %% [markdown]
# #### Load "observations" - ERA5-land (1991 - 2010)

# %%
years = np.arange(1991, 2011)
path = 'O:/Climate-and-Energy-Policy/CERM/Projects/Wildfire/Data/ERA5-land/regrided/FWI-variables/'

files = []

for year in years:
    year = str(year)

    files = files + sorted(glob.glob(path + var + '-' + year +'*.nc'))[5:10] # Select only June to October


len(files)/5 # Only considering 5months / year
# Out:
# 20.0

# %%
# %%time
ds_obs = xr.open_mfdataset(files).wind /0.001/3600 #km/hr to m/s
# Out:
# CPU times: total: 18.5 s
# Wall time: 44.5 s

# %%
# Remove leap days 
ds_obs = ds_obs.sel(time = ~((ds_obs.time.dt.month == 2) & (ds_obs.time.dt.day == 29)))
ds_obs = ds_obs.chunk(chunks={'y': 20, 'x': 20, 'time': -1})

# %%
len(ds_obs.time)
# Out:
# 3060

# %% [markdown]
# ### 3. Future data to bias correct: Select 20 year period

# %%
years = np.arange(int(start_year), int(end_year) + 1)
path = "O:/Climate-and-Energy-Policy/CERM/Projects/Wildfire/Data/CLIMEX2/FWI-variables/"

files = []

for year in years:
    year = str(year)
    files = files + sorted(glob.glob(path +'/'+ ens + '/' + var + '-' + year + '*.nc')) # Select only June to October

# %%
len(files)/5
# Out:
# 20.0

# %%
# %%time
ds_fut = xr.open_mfdataset(files)
# Out:
# CPU times: total: 41.6 s
# Wall time: 1min

# %%
# Select midday timestep
ds_fut = ds_fut.wind

# %%
ds_fut = ds_fut.chunk(chunks={'rlat': 20, 'rlon': 20, 'time': -1})

# %%
len(ds_fut.time)
# Out:
# 3060

# %% [markdown]
# ### 4. Debias data
#
# Ibicus has an option to use dask to apply the debiaser which makes it possible to bias correct the data in Europe for a 20 year period.

# %%
if bias_correct == 'QM':
    debiaser = QuantileMapping.from_variable(variable = 'sfcwind')
elif bias_correct == 'LS':
    debiaser = LinearScaling.from_variable(variable = 'sfcwind')
elif bias_correct == 'SDM':
    debiaser = ScaledDistributionMapping.from_variable(variable ='sfcwind')
elif bias_correct == 'ISIMIP':
    debiaser = ISIMIP.from_variable(variable = 'sfcwind')
else:
    print('Not available. Options available are QM, LS, DC or SDM')
# Out:
# C:\Users\ophme\AppData\Local\anaconda3\envs\wildfire\Lib\site-packages\ibicus\debias\_linear_scaling.py:112: UserWarning: The default settings for variable sfcwind in debiaser LinearScaling are currently still experimental and may not have been evaluated in the peer-reviewed literature. Please review the results with care!
#   return super()._from_variable(

# %%
# %%time 
collection = da.map_blocks(debiaser.apply, ds_obs.data, ds_hist.data, ds_fut.data, dtype=ds_obs.dtype, progressbar = False, parallel = False, failsafe = True)
debiased_cm_future = collection.compute(num_workers=8)
# Out:
# CPU times: total: 40.3 s
# Wall time: 1min 31s

# %% [markdown]
# ### 5. Save data

# %%
# Create folder to save data to 
save_path = 'O:/Climate-and-Energy-Policy/CERM/Projects/Wildfire/Data/CLIMEX2/debiased/' + var + '/'+ ens + '/'
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# %%
ds_fut_new = ds_fut.copy()
ds_fut_debias = ds_fut_new.to_dataset()
ds_fut_debias = ds_fut_debias.drop_vars(var)
ds_fut_debias = ds_fut_debias.assign(wind = (['time', 'rlat', 'rlon'], debiased_cm_future))
ds_fut_debias.to_netcdf(save_path + var + '_' + start_year + '-' + end_year + '_' + bias_correct +'.nc')

# %%
t1 = time.time()
print((t1 - t0)/60)
# Out:
# 7.6309453328450525

# %%
fut = ds_fut_debias.wind.values

# %%
hist = ds_hist.values

# %%
hist[np.isnan(fut)] = np.nan

# %%
obs = ds_obs.values

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.pcolor(np.nanmean(hist, axis = 0) - np.nanmean(obs, axis = 0), vmin = -5, vmax = 5, cmap = 'bwr' )
ax.plot(200, 200, 'kx')
ax.plot(320, 160, 'ko')
# Out:
# C:\Users\ophme\AppData\Local\Temp\ipykernel_16784\4207610190.py:3: RuntimeWarning: Mean of empty slice
#   ax.pcolor(np.nanmean(hist, axis = 0) - np.nanmean(obs, axis = 0), vmin = -5, vmax = 5, cmap = 'bwr' )

# %%
fig, ax = plt.subplots(2, 1, sharex = True)
ax[0].hist(obs[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = 'obs', lw = 2, cumulative=True)
ax[0].hist(fut[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = bias_correct, lw = 1.2, cumulative=True)
ax[0].hist(hist[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = 'climex', lw = 1.2, cumulative=True)
ax[0].legend()
ax[0].set_title('location x')

ax[1].hist(obs[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = 'obs', lw = 2, cumulative=True)
ax[1].hist(fut[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = bias_correct, lw = 1.2, cumulative=True)
ax[1].hist(hist[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = 'climex', lw = 1.2, cumulative=True)
ax[1].legend()
ax[1].set_title('location o')
# Out:
# Text(0.5, 1.0, 'location o')

# %%
fig, ax = plt.subplots(2, 1, sharex = True)
ax[0].hist(obs[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = 'obs', lw = 2)
ax[0].hist(fut[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = bias_correct, lw = 1.2)
ax[0].hist(hist[:, 200, 200], bins = np.arange(0, 10, 0.2), histtype='step', label = 'climex', lw = 1.2)
ax[0].legend()
ax[0].set_title('location x')

ax[1].hist(obs[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = 'obs', lw = 2)
ax[1].hist(fut[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = bias_correct, lw = 1.2)
ax[1].hist(hist[:, 160, 320], bins = np.arange(0, 10, 0.2), histtype='step', label = 'climex', lw = 1.2)
ax[1].legend()
ax[1].set_title('location o')
# Out:
# Text(0.5, 1.0, 'location o')

# %%
fig, ax = plt.subplots(2, 1, sharex = True)
ax[0].plot(obs[:, 200, 200], label = 'obs', lw = 2)
ax[0].plot(fut[:, 200, 200], label = 'LS', lw = 1.2)
ax[0].plot(hist[:, 200, 200], label = 'climex', lw = 1.2)
ax[0].legend()
ax[0].set_title('location x')

ax[1].plot(obs[:, 160, 320], label = 'obs', lw = 2)
ax[1].plot(fut[:, 160, 320], label = 'LS', lw = 1.2)
ax[1].plot(hist[:, 160, 320], label = 'climex', lw = 1.2)
ax[1].legend()
ax[1].set_title('location o')
ax[0].set_xlim(0, 154)
# Out:
# (0.0, 154.0)

# %%
day = 100
fig, ax = plt.subplots(2, 1, sharex = True)
a = ax[0].contourf(hist[day, :, :] - obs[day, :, :] , levels = np.arange(-15, 14, 2), cmap = 'bwr', extend = 'both' )
ax[0].plot(200, 200, 'kx')
ax[0].plot(320, 160, 'ko')
ax[1].contourf(fut[day, :, :] - obs[day, :, :] , levels = np.arange(-15, 14, 2), cmap = 'bwr', extend = 'both' )
ax[1].plot(200, 200, 'kx')
ax[1].plot(320, 160, 'ko')
fig.colorbar(a, ax = ax[:])
ax[0].set_title('historical - obs')
ax[1].set_title('QM - obs')
# Out:
# Text(0.5, 1.0, 'QM - obs')

# %%
print(np.nanmean(obs[:, 200, 200]))
print(np.nanmean(hist[:, 200, 200]))
print(np.nanmean(fut[:, 200, 200]))
# Out:
# 3.76633814570258
# 2.5201042
# 3.7663383

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(debiased_cm_future.flatten(), bins = np.arange(0, 10, 0.1), histtype='step', label = bias_correct)
ax.hist(hist.flatten(), bins = np.arange(0, 10, 0.1), histtype='step', label = 'climex')
ax.hist(obs.flatten(), bins = np.arange(0, 10, 0.1), histtype='step', label = 'obs')
ax.legend()

# %%
exit()
